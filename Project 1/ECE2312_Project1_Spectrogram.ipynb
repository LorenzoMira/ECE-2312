# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np

# Defining Sampling Rate (Frequency) in Hz
sr = 44100

# Load the audio file
x, sr = librosa.load('phrase3.wav')

# Compute the spectrogram
D = librosa.amplitude_to_db(librosa.stft(x, hop_length=512, n_fft=2048), ref=np.max)

# Display the spectrogram
plt.figure(figsize=(14, 5))
librosa.display.specshow(D, sr=sr, x_axis='time', y_axis='log')
plt.colorbar(format='%+2.0f dB')
plt.title('Spectrogram of Phrase 3')
plt.xlabel('Time (s)')
plt.xlim(0, 5)
plt.ylabel('Frequency (Hz)')
plt.ylim(0, 8000)
plt.show()
# Out:
# C:\Users\clend\AppData\Local\Temp\ipykernel_19140\4032685862.py:13: UserWarning: amplitude_to_db was called on complex input so phase information will be discarded. To suppress this warning, call amplitude_to_db(np.abs(S)) instead.
#   D = librosa.amplitude_to_db(librosa.stft(x, hop_length=512, n_fft=2048), ref=np.max)
